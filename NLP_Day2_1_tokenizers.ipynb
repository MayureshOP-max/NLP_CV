# %% [markdown]
# <a href="https://colab.research.google.com/github/MayureshOP-max/NLP_CV/blob/main/NLP_Day2_1_tokenizers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import numpy as np
import nltk
nltk.download('punkt') #tokenization
nltk.download('stopwords')  #collection of stopwords
nltk.download('wordnet')  #wordnet-> database of english words
nltk.download('omw-1.4')  #Open multilingual wordnet
nltk.download('averaged_perceptron_tagger')  #POS tagging
nltk.download('indian')  #Indian language POS tagging
nltk.download('maxent_ne_chunker')  #NER tagging
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package indian to /root/nltk_data...
# [nltk_data]   Unzipping corpora/indian.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# True

# %%
from nltk.tokenize import word_tokenize
import string

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
sents = '''मराठी भाषा ही इंडो-युरोपीय भाषाकुळातील एक भाषा आहे. मराठी ही भारताच्या २२ अधिकृत भाषांपैकी एक आहे.
मराठी महाराष्ट्र राज्याची अधिकृत तर गोवा राज्याची सहअधिकृत भाषा आहे. २०११ च्या जनगणनेनुसार, भारतात मराठी भाषकांची एकूण लोकसंख्या सुमारे १४ कोटी आहे.
 मराठी मातृभाषा असणाऱ्या लोकांच्या संख्येनुसार मराठी ही जगातील दहावी व भारतातील तिसरी भाषा आहे. मराठी भाषा भारताच्या प्राचीन भाषांपैकी एक असून महाराष्ट्री प्राकृतचे आधुनिक रूप आहे.
 मराठीचे वय सुमारे २४०० वर्ष आहे. महाराष्ट्र हे मराठी भाषिकांचे राज्य म्हणून मराठी भाषेला वेगळे महत्त्व प्राप्त झालेले आहे.
  आजतागायत मराठी भाषेतून अनेक श्रेष्ठ साहित्यकृती निर्माण झालेल्या आहेत आणि त्यात सातत्यपूर्ण रीतीने भर पडत आहे.
 गोवा गुजरात सारख्या राज्यातही मराठी भाषा काही प्रमाणात बोलली जाते. गोव्यात मराठीला समृद्ध असा इतिहास आहे.
 भारतीय केंद्र सरकारने मराठी भाषेला अभिजात भाषा म्हणून घोषित केले आहे .३ ऑक्टोबर २ ० २ ४ रोजी हा निर्णय जाहीर करण्यात आला आहे .[२] मराठी भाषा इसवी सनापूर्वी अस्तित्वात होती यासाठी प्रा. हरी नरके यांनी मांडलेले मुद्दे :-

इसवी सनापूर्वी २०७ या वर्षी ब्राह्मी लिपीत परंतु मराठी भाषेत लिहिलेले शिलालेख सापडले आहेत.
गाथा सप्तशती हा ७०० श्लोकांचा मराठी ग्रंथ इसवी सनाच्या पहिल्या शतकात लिहिला गेला. त्याचा अर्थ असा की ही भाषा त्या लिखाणाआधी किमान ३०० वर्षे अस्तित्वात असली पाहिजे. ग्रंथातील वर्णन आजही मराठी लोकांच्या आचार-विचारांशी आणि त्यांच्या सध्याच्या संस्कृतीशी जुळणारे आहे. ग्रंथात वापरलेले गेलेले काही शब्द मराठीखेरीज अन्य भारतीय भाषेत नाहीत.
भांडारकर पुरातत्त्व संशोधन संस्थेमध्ये किमान ८० हस्तलिखिते मराठी भाषेचे पुराणत्व सिद्ध करणारी आहेत.[३]
मराठी भाषा भाषिक प्रदेश
मराठी भाषा मुख्यत्वे भारताच्या महाराष्ट्र राज्यात बोलली जाते. त्याचबरोबर गोवा, उत्तर कर्नाटक (बेळगाव, हुबळी-धारवाड, गुलबर्गा, बिदर, कारवार), गुजरात (दक्षिण गुजरात, सुरत, बडोदा व अहमदाबाद), आंध्रप्रदेश (हैदराबाद), मध्यप्रदेश (इंदूर, ग्वाल्हेर), तामिळनाडू (तंजावर) व छत्तीसगढ राज्यांत आणि दमण आणि दीव, दादरा नगर हवेली या संघराज्यशासित प्रदेशांतील काही भागातही मराठी बोलली जाते. देशातील ९ राज्ये, ४ संघराज्यशासित प्रदेश आणि ११३ देशांमध्ये मराठी भाषिकांची वस्ती आहे. इतरही अनेक देशांमध्ये मराठी भाषा बोलण्याचे प्रमाण वाढत आहे.

मराठी भाषा भारतासह, फिजी, मॉरिशस व इस्रायल या देशांतही बोलली जाते.[४] त्याचबरोबर जगभरात विखुरलेल्या मराठी-भाषकांमुळे मराठी अमेरिकेची संयुक्त संस्थाने, संयुक्त अरब अमिरात, दक्षिण आफ्रिका, पाकिस्तान, सिंगापूर, जर्मनी, युनायटेड किंग्डम, ऑस्ट्रेलिया व न्यू झीलंड येथेही बोलली जाते.[५]

राजभाषा
भारतीय राज्यघटनेतील २२ अधिकृत भाषांच्या यादीत मराठीचा समावेश आहे.महाराष्ट्राची मायबोली मराठी असल्याने महाराष्ट्र दिनानिमित्त 'मराठी राजभाषा दिन' अर्थात 'मराठी भाषा दिन' १ मे रोजी साजरा करण्याचा ऐतिहासिक निर्णय आधुनिक महाराष्ट्राचे शिल्पकार वसंतराव नाईक यांनी घेतला. तत्कालिन मुख्यमंत्री वसंतराव नाईक यांच्या सरकारने 'मराठी राजभाषा अधिनियम 1964' सर्वप्रथम 11 जानेवारी 1965 रोजी प्रसिद्ध केला. या अधिनियमानुसार, महाराष्ट्राची अधिकृत राजभाषा ही मराठी असेल असे जाहीर करण्यात आले. त्यानंतर 1966 पासून या निर्णयाची अंमलबजावणी सुरू झाली. मराठीला राजभाषेचा दर्जा देऊन जणू मराठीचे राज्यभिषेक करून आधुनिक महाराष्ट्राचे शिल्पकार वसंंतराव नाईक सरकारने मराठीचा ऐतिहासिक गौरव केला.

मराठी ही महाराष्ट्र राज्याची एकमेव अधिकृत राजभाषा आहे. गोवा राज्यात नियमानुसार कोकणी ही राजभाषा असली तरी मराठीचा वापर शासनाच्या सर्व कारणासाठी होऊ शकतो. शासनाशी मराठीत होणाऱ्या पत्रव्यवहाराचे उत्तर मराठीतच दिले जाते. दादरा व नगर हवेली[६] या संघराज्यशासित प्रदेशात मराठी एक अधिकृत राजभाषा आहे.

महाराष्ट्रातील सर्व विद्यापीठांत मराठीच्या उच्च शिक्षणाची सोय आहे तसेच महाराष्ट्राबाहेरील गोवा विद्यापीठ (पणजी)[७], महाराजा सयाजीराव विद्यापीठ (बडोदे)[८], उस्मानिया विद्यापीठ (तेलंगणा), गुलबर्गा विद्यापीठ[९], देवी अहिल्या विद्यापीठ (इंदूर)[१०] व जवाहरलाल नेहरू विश्वविद्यालय (नवी दिल्ली)[११] येथे मराठी उच्चशिक्षण विभाग आहेत. महाराष्ट्राबाहेरील एकूण १५ विद्यापीठांमध्ये मराठी शिकविली जाते.'''

# %%
sents
# Out:
# "मराठी भाषा ही इंडो-युरोपीय भाषाकुळातील एक भाषा आहे. मराठी ही भारताच्या २२ अधिकृत भाषांपैकी एक आहे. \nमराठी महाराष्ट्र राज्याची अधिकृत तर गोवा राज्याची सहअधिकृत भाषा आहे. २०११ च्या जनगणनेनुसार, भारतात मराठी भाषकांची एकूण लोकसंख्या सुमारे १४ कोटी आहे.\n मराठी मातृभाषा असणाऱ्या लोकांच्या संख्येनुसार मराठी ही जगातील दहावी व भारतातील तिसरी भाषा आहे. मराठी भाषा भारताच्या प्राचीन भाषांपैकी एक असून महाराष्ट्री प्राकृतचे आधुनिक रूप आहे. \n मराठीचे वय सुमारे २४०० वर्ष आहे. महाराष्ट्र हे मराठी भाषिकांचे राज्य म्हणून मराठी भाषेला वेगळे महत्त्व प्राप्त झालेले आहे.\n  आजतागायत मराठी भाषेतून अनेक श्रेष्ठ साहित्यकृती निर्माण झालेल्या आहेत आणि त्यात सातत्यपूर्ण रीतीने भर पडत आहे.\n गोवा गुजरात सारख्या राज्यातही मराठी भाषा काही प्रमाणात बोलली जाते. गोव्यात मराठीला समृद्ध असा इतिहास आहे.\n भारतीय केंद्र सरकारने मराठी भाषेला अभिजात भाषा म्हणून घोषित केले आहे .३ ऑक्टोबर २ ० २ ४ रोजी हा निर्णय जाहीर करण्यात आला आहे .[२] मराठी भाषा इसवी सनापूर्वी अस्तित्वात होती यासाठी प्रा. हरी नरके यांनी मांडलेले मुद्दे
# ...

# %%
tokens = word_tokenize(sents)

# %% [markdown]
# # **Types of tokenization**

# %%
tokens
# Out:
# ['मराठी',
#  'भाषा',
#  'ही',
#  'इंडो-युरोपीय',
#  'भाषाकुळातील',
#  'एक',
#  'भाषा',
#  'आहे',
#  '.',
#  'मराठी',
#  'ही',
#  'भारताच्या',
#  '२२',
#  'अधिकृत',
#  'भाषांपैकी',
#  'एक',
#  'आहे',
#  '.',
#  'मराठी',
#  'महाराष्ट्र',
#  'राज्याची',
#  'अधिकृत',
#  'तर',
#  'गोवा',
#  'राज्याची',
#  'सहअधिकृत',
#  'भाषा',
#  'आहे',
#  '.',
#  '२०११',
#  'च्या',
#  'जनगणनेनुसार',
#  ',',
#  'भारतात',
#  'मराठी',
#  'भाषकांची',
#  'एकूण',
#  'लोकसंख्या',
#  'सुमारे',
#  '१४',
#  'कोटी',
#  'आहे',
#  '.',
#  'मराठी',
#  'मातृभाषा',
#  'असणाऱ्या',
#  'लोकांच्या',
#  'संख्येनुसार',
#  'मराठी',
#  'ही',
#  'जगातील',
#  'दहावी',
#  'व',
#  'भारतातील',
#  'तिसरी',
#  'भाषा',
#  'आहे',
#  '.',
#  'मराठी',
#  'भाषा',
#  'भारताच्या',
#  'प्राचीन',
#  'भाषांपैकी',
#  'एक',
#  'असून',
#  'महाराष्ट्री',
#  'प्राकृतचे',
#  'आधुनिक',
#  'रूप',
#  'आहे',
#  '.',
#  'मराठीचे',
#  'वय',
#  'सुमारे',
#  '२४००',
#  'वर्ष',
#  'आहे',
#  '.',
#  'महाराष्ट्र',
#  'हे',
#  'मराठी',
#  'भाषिकांचे',
# ...

# %%
##### Sentence Tokenization

from nltk.tokenize import sent_tokenize

# %%
text = '''Hello friends!
How are you? Wel    come to the world of Python Programming.'''

# %%
sent_tokenize(text)
# Out:
# ['Hello friends!',
#  'How are you?',
#  'Wel    come to the world of Python Programming.']

# %%
sent_tokenize(sents)
# Out:
# ['मराठी भाषा ही इंडो-युरोपीय भाषाकुळातील एक भाषा आहे.',
#  'मराठी ही भारताच्या २२ अधिकृत भाषांपैकी एक आहे.',
#  'मराठी महाराष्ट्र राज्याची अधिकृत तर गोवा राज्याची सहअधिकृत भाषा आहे.',
#  '२०११ च्या जनगणनेनुसार, भारतात मराठी भाषकांची एकूण लोकसंख्या सुमारे १४ कोटी आहे.',
#  'मराठी मातृभाषा असणाऱ्या लोकांच्या संख्येनुसार मराठी ही जगातील दहावी व भारतातील तिसरी भाषा आहे.',
#  'मराठी भाषा भारताच्या प्राचीन भाषांपैकी एक असून महाराष्ट्री प्राकृतचे आधुनिक रूप आहे.',
#  'मराठीचे वय सुमारे २४०० वर्ष आहे.',
#  'महाराष्ट्र हे मराठी भाषिकांचे राज्य म्हणून मराठी भाषेला वेगळे महत्त्व प्राप्त झालेले आहे.',
#  'आजतागायत मराठी भाषेतून अनेक श्रेष्ठ साहित्यकृती निर्माण झालेल्या आहेत आणि त्यात सातत्यपूर्ण रीतीने भर पडत आहे.',
#  'गोवा गुजरात सारख्या राज्यातही मराठी भाषा काही प्रमाणात बोलली जाते.',
#  'गोव्यात मराठीला समृद्ध असा इतिहास आहे.',
#  'भारतीय केंद्र सरकारने मराठी भाषेला अभिजात भाषा म्हणून घोषित केले आहे .३ ऑक्टोबर २ ० २ ४ रोजी हा निर्णय जाहीर करण्यात आला आहे .',
# ...

# %%
india = '''India, officially the Republic of India,[j][20] is a country in South Asia. It is the seventh-largest country in the world by area and the most populous country. Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[k] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is in the vicinity of Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Thailand, Myanmar, and Indonesia.
Modern humans arrived on the Indian subcontinent from Africa no later than 55,000 years ago.[22][23][24] Their long occupation, initially in varying forms of isolation as hunter-gatherers, has made the region highly diverse, second only to Africa in human genetic diversity.[25] Settled life emerged on the subcontinent in the western margins of the Indus river basin 9,000 years ago, evolving gradually into the Indus Valley Civilisation of the third millennium BCE.[26] By at least 1200 BCE, an archaic form of Sanskrit, an Indo-European language, had diffused into India from the northwest.[27][28] Its evidence today is found in the hymns of the Rigveda. Preserved by an oral tradition that was resolutely vigilant, the Rigveda records the dawning of Hinduism in India.[29] The Dravidian languages of India were supplanted in the northern and western regions.[30] By 400 BCE, stratification and exclusion by caste had emerged within Hinduism,[31] and Buddhism and Jainism had arisen, proclaiming social orders unlinked to heredity.[32] Early political consolidations gave rise to the loose-knit Maurya and Gupta Empires based in the Ganges Basin.[33] Their collective era was suffused with wide-ranging creativity,[34] but also marked by the declining status of women,[35] and the incorporation of untouchability into an organised system of belief.[l][36] The Middle kingdoms exported Sanskrit language, south Indian scripts and religions of Hinduism and Buddhism to the Southeast Asia.[37]'''

# %%
india
# Out:
# 'India, officially the Republic of India,[j][20] is a country in South Asia. It is the seventh-largest country in the world by area and the most populous country. Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[k] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is in the vicinity of Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Thailand, Myanmar, and Indonesia.\nModern humans arrived on the Indian subcontinent from Africa no later than 55,000 years ago.[22][23][24] Their long occupation, initially in varying forms of isolation as hunter-gatherers, has made the region highly diverse, second only to Africa in human genetic diversity.[25] Settled life emerged on the subcontinent in the western margins of the Indus river basin 9,000 years ago, evolving gradually into the I
# ...

# %%
# print sentence which contains maximum number of terms
tok = sent_tokenize(india)
tok
# Out:
# ['India, officially the Republic of India,[j][20] is a country in South Asia.',
#  'It is the seventh-largest country in the world by area and the most populous country.',
#  'Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[k] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east.',
#  'In the Indian Ocean, India is in the vicinity of Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Thailand, Myanmar, and Indonesia.',
#  'Modern humans arrived on the Indian subcontinent from Africa no later than 55,000 years ago.',
#  '[22][23][24] Their long occupation, initially in varying forms of isolation as hunter-gatherers, has made the region highly diverse, second only to Africa in human genetic diversity.',
# ...

# %%
lst = [len(x) for x in tok]

# %%
import numpy as np
tok[np.argmax(lst)]
# Out:
# 'Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[k] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east.'

# %%
lst2 = []
for i in tok:
    cnt = i.count('the')
    lst2.append(cnt)
tok[np.argmax(lst2)]
# Out:
# 'Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[k] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east.'

# %%
max = 0
for sent in sent_tokenize(india):
    count = word_tokenize(sent.lower()).count('the')
    if count > max:
        max = count
        final_sent =sent

# %%
final_sent
# Out:
# 'Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[k] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east.'

# %% [markdown]
# # **WhiteSpace tokenizer**
# **Space**
#
# **Tab  \t**
#
# **New line  \n**

# %%
from nltk.tokenize import WhitespaceTokenizer, SpaceTokenizer

# %%
tk = WhitespaceTokenizer()

# %%
text
# Out:
# 'Hello friends!\nHow are you? Wel    come to the world of Python Programming.'

# %%
tk.tokenize(text)
# Out:
# ['Hello',
#  'friends!',
#  'How',
#  'are',
#  'you?',
#  'Wel',
#  'come',
#  'to',
#  'the',
#  'world',
#  'of',
#  'Python',
#  'Programming.']

# %%
# space tokenizer
tk = SpaceTokenizer()

# %%
tk.tokenize(text)
# Out:
# ['Hello',
#  'friends!\nHow',
#  'are',
#  'you?',
#  'Wel',
#  '',
#  '',
#  '',
#  'come',
#  'to',
#  'the',
#  'world',
#  'of',
#  'Python',
#  'Programming.']

# %%
# Line tokenizer
from nltk.tokenize import LineTokenizer
tk1 = LineTokenizer()

# %%
tk1.tokenize(text)
# Out:
# ['Hello friends!',
#  'How are you? Wel    come to the world of Python Programming.']

# %%
# Tab tokenizer
from nltk.tokenize import TabTokenizer
tk2 = TabTokenizer()

# %%
text1 = '''Hello\tfriends!
How are you? Welcome to the world of\tPython Programming.'''

# %%
print(text1)
# Out:
# Hello	friends!
# How are you? Welcome to the world of	Python Programming.

# %%
tk2.tokenize(text1)
# Out:
# ['Hello',
#  'friends!\nHow are you? Welcome to the world of',
#  'Python Programming.']

# %% [markdown]
# # Tweet Tokenizer

# %%
from nltk.tokenize import TweetTokenizer

# %%
data = '''Hello friends!:) How are you? Welcome to😜 the :$ world of Python <3 :\ ;} Programming❤️.'''

# %%
tk = TweetTokenizer()

# %%
tk.tokenize(data)
# Out:
# ['Hello',
#  'friends',
#  '!',
#  ':)',
#  'How',
#  'are',
#  'you',
#  '?',
#  'Welcome',
#  'to',
#  '😜',
#  'the',
#  ':',
#  '$',
#  'world',
#  'of',
#  'Python',
#  '<3',
#  ':\\',
#  ';}',
#  'Programming',
#  '❤',
#  '️',
#  '.']

# %%
word_tokenize(data)
# Out:
# ['Hello',
#  'friends',
#  '!',
#  ':',
#  ')',
#  'How',
#  'are',
#  'you',
#  '?',
#  'Welcome',
#  'to😜',
#  'the',
#  ':',
#  '$',
#  'world',
#  'of',
#  'Python',
#  '<',
#  '3',
#  ':',
#  '\\',
#  ';',
#  '}',
#  'Programming❤️',
#  '.']

# %% [markdown]
# # **MWE Tokenizer(mutli word extension)**

# %%
### mwe tokenizer
from nltk.tokenize import MWETokenizer

# %%
data = 'Van Rossom is in Pune today. We welcomed Van Rossom here.'

# %%
tk = MWETokenizer(separator=' ')

# %%
tk.add_mwe(('Van', 'Rossom'))

# %%
tk.tokenize(word_tokenize(data))
# Out:
# ['Van Rossom',
#  'is',
#  'in',
#  'Pune',
#  'today',
#  '.',
#  'We',
#  'welcomed',
#  'Van Rossom',
#  'here',
#  '.']

# %% [markdown]
# # **Custom Tokenizer**

# %%
def custom_tokenizer(text):
    return re.split(r'[.,:?!\s]+', text)
text = "This is some text with punctuation > let's tokenize it. Is it ok?"
tokens = custom_tokenizer(text)


for token in tokens:
    print(token)
# Out:
# This
# is
# some
# text
# with
# punctuation
# >
# let's
# tokenize
# it
# Is
# it
# ok
