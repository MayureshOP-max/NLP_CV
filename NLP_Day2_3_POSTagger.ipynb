# %% [markdown]
# <a href="https://colab.research.google.com/github/MayureshOP-max/NLP_CV/blob/main/NLP_Day2_3_POSTagger.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
from nltk import pos_tag
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
text = '''
India, officially the Republic of India,[j][20] is a country in South Asia. It is the seventh-largest country in the world by area and the most populous country. Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[k] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is in the vicinity of Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Thailand, Myanmar, and Indonesia.

Modern humans arrived on the Indian subcontinent from Africa no later than 55,000 years ago.[22][23][24] Their long occupation, initially in varying forms of isolation as hunter-gatherers, has made the region highly diverse, second only to Africa in human genetic diversity.[25] Settled life emerged on the subcontinent in the western margins of the Indus river basin 9,000 years ago, evolving gradually into the Indus Valley Civilisation of the third millennium BCE.[26] By at least 1200 BCE, an archaic form of Sanskrit, an Indo-European language, had diffused into India from the northwest.[27][28] Its evidence today is found in the hymns of the Rigveda. Preserved by an oral tradition that was resolutely vigilant, the Rigveda records the dawning of Hinduism in India.[29] The Dravidian languages of India were supplanted in the northern and western regions.[30] By 400 BCE, stratification and exclusion by caste had emerged within Hinduism,[31] and Buddhism and Jainism had arisen, proclaiming social orders unlinked to heredity.[32] Early political consolidations gave rise to the loose-knit Maurya and Gupta Empires based in the Ganges Basin.[33] Their collective era was suffused with wide-ranging creativity,[34] but also marked by the declining status of women,[35] and the incorporation of untouchability into an organised system of belief.[l][36] The Middle kingdoms exported Sanskrit language, south Indian scripts and religions of Hinduism and Buddhism to the Southeast Asia.[37]

In the early mediaeval era, Christianity, Islam, Judaism, and Zoroastrianism became established on India's southern and western coasts.[38] Muslim armies from Central Asia intermittently overran India's northern plains,[39] eventually founding the Delhi Sultanate and drawing northern India into the cosmopolitan networks of mediaeval Islam.[40] In the 15th century, the Vijayanagara Empire created a long-lasting composite Hindu culture in south India.[41] In the Punjab, Sikhism emerged, rejecting institutionalised religion.[42] The Mughal Empire, in 1526, ushered in two centuries of relative peace,[43] leaving a legacy of luminous architecture.[m][44] Gradually expanding rule of the British East India Company followed, turning India into a colonial economy but also consolidating its sovereignty.[45] British Crown rule began in 1858. The rights promised to Indians were granted slowly,[46][47] but technological changes were introduced, and modern ideas of education and public life took root.[48] A pioneering and influential nationalist movement emerged, which was noted for nonviolent resistance and became the major factor in ending British rule.[49][50] In 1947, the British Indian Empire was partitioned into two independent dominions,[51][52][53][54] a Hindu-majority dominion of India and a Muslim-majority dominion of Pakistan, amid large-scale loss of life and an unprecedented migration.[55]'''

# %%
pos = pos_tag(word_tokenize(text))

# %%
pos
# Out:
# [('India', 'NNP'),
#  (',', ','),
#  ('officially', 'RB'),
#  ('the', 'DT'),
#  ('Republic', 'NNP'),
#  ('of', 'IN'),
#  ('India', 'NNP'),
#  (',', ','),
#  ('[', 'NNP'),
#  ('j', 'NN'),
#  (']', 'NNP'),
#  ('[', 'VBZ'),
#  ('20', 'CD'),
#  (']', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('country', 'NN'),
#  ('in', 'IN'),
#  ('South', 'NNP'),
#  ('Asia', 'NNP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('seventh-largest', 'JJ'),
#  ('country', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('by', 'IN'),
#  ('area', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('populous', 'JJ'),
#  ('country', 'NN'),
#  ('.', '.'),
#  ('Bounded', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('Indian', 'JJ'),
#  ('Ocean', 'NNP'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('south', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Arabian', 'NNP'),
#  ('Sea', 'NNP'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('southwest', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Bay', 'NNP'),
#  ('of', 'IN'),
#  ('Bengal', 'NNP'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('southeast', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('shares', 'NNS'),
#  ('land', 'VBZ'),
#  ('borders', 'NNS'),
#  ('with', 'IN'),
#  ('Pakistan', 'NNP'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('west', 'NN'),
#  (';', ':'),
#  ('[', 'CC'),
#  ('k', 'VB'),
#  (']', 'NNP'),
#  ('China', 'NNP'),
#  (',', ','),
#  ('Nepal', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('Bhutan', 'NNP'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('north', 'NN'),
#  (';', ':'),
#  ('and', 'CC'),
#  ('Bangladesh', 'NNP'),
#  ('and', 'CC'),
#  ('Myanmar', 'NNP'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('east', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('Indian', 'JJ'),
#  ('Ocean', 'NNP'),
#  (',', ','),
#  ('India', 'NNP'),
#  ('is', 'VBZ'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('vicinity', 'NN'),
#  ('of', 'IN'),
#  ('Sri', 'NNP'),
#  ('Lanka', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Maldives', 'NNPS'),
#  (';', ':'),
#  ('its', 'PRP$'),
#  ('Andaman', 'NNP'),
#  ('and', 'CC'),
#  ('Nicobar', 'NNP'),
#  ('Islands', 'NNP'),
#  ('share', 'NN'),
#  ('a', 'DT'),
#  ('maritime', 'NN'),
#  ('border', 'NN'),
#  ('with', 'IN'),
#  ('Thailand', 'NNP'),
#  (',', ','),
#  ('Myanmar', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('Indonesia', 'NNP'),
#  ('.', '.'),
#  ('Modern', 'NNP'),
#  ('humans', 'VBZ'),
#  ('arrived', 'VBN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('Indian', 'JJ'),
#  ('subcontinent', 'NN'),
#  ('from', 'IN'),
#  ('Africa', 'NNP'),
#  ('no', 'RB'),
#  ('later', 'RB'),
#  ('than', 'IN'),
#  ('55,000', 'CD'),
#  ('years', 'NNS'),
#  ('ago', 'RB'),
#  ('.', '.'),
#  ('[', 'VB'),
#  ('22', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('23', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('24', 'CD'),
#  (']', 'NNS'),
#  ('Their', 'PRP$'),
#  ('long', 'JJ'),
#  ('occupation', 'NN'),
#  (',', ','),
#  ('initially', 'RB'),
#  ('in', 'IN'),
#  ('varying', 'VBG'),
#  ('forms', 'NNS'),
#  ('of', 'IN'),
#  ('isolation', 'NN'),
#  ('as', 'IN'),
#  ('hunter-gatherers', 'NNS'),
#  (',', ','),
#  ('has', 'VBZ'),
#  ('made', 'VBN'),
#  ('the', 'DT'),
#  ('region', 'NN'),
#  ('highly', 'RB'),
#  ('diverse', 'JJ'),
#  (',', ','),
#  ('second', 'JJ'),
#  ('only', 'RB'),
#  ('to', 'TO'),
#  ('Africa', 'NNP'),
#  ('in', 'IN'),
#  ('human', 'JJ'),
#  ('genetic', 'JJ'),
#  ('diversity', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('25', 'CD'),
#  (']', 'NN'),
#  ('Settled', 'VBD'),
#  ('life', 'NN'),
#  ('emerged', 'VBN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('subcontinent', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('western', 'JJ'),
#  ('margins', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Indus', 'NNP'),
#  ('river', 'NN'),
#  ('basin', 'NN'),
#  ('9,000', 'CD'),
#  ('years', 'NNS'),
#  ('ago', 'RB'),
#  (',', ','),
#  ('evolving', 'VBG'),
#  ('gradually', 'RB'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('Indus', 'NNP'),
#  ('Valley', 'NNP'),
#  ('Civilisation', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('third', 'JJ'),
#  ('millennium', 'NN'),
#  ('BCE', 'NNP'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('26', 'CD'),
#  (']', 'NN'),
#  ('By', 'IN'),
#  ('at', 'IN'),
#  ('least', 'JJS'),
#  ('1200', 'CD'),
#  ('BCE', 'NNP'),
#  (',', ','),
#  ('an', 'DT'),
#  ('archaic', 'JJ'),
#  ('form', 'NN'),
#  ('of', 'IN'),
#  ('Sanskrit', 'NNP'),
#  (',', ','),
#  ('an', 'DT'),
#  ('Indo-European', 'JJ'),
#  ('language', 'NN'),
#  (',', ','),
#  ('had', 'VBD'),
#  ('diffused', 'VBN'),
#  ('into', 'IN'),
#  ('India', 'NNP'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('northwest', 'JJS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('27', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('28', 'CD'),
#  (']', 'CC'),
#  ('Its', 'PRP$'),
#  ('evidence', 'NN'),
#  ('today', 'NN'),
#  ('is', 'VBZ'),
#  ('found', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('hymns', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Rigveda', 'NNP'),
#  ('.', '.'),
#  ('Preserved', 'VBN'),
#  ('by', 'IN'),
#  ('an', 'DT'),
#  ('oral', 'JJ'),
#  ('tradition', 'NN'),
#  ('that', 'WDT'),
#  ('was', 'VBD'),
#  ('resolutely', 'RB'),
#  ('vigilant', 'JJ'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Rigveda', 'NNP'),
#  ('records', 'NNS'),
#  ('the', 'DT'),
#  ('dawning', 'NN'),
#  ('of', 'IN'),
#  ('Hinduism', 'NNP'),
#  ('in', 'IN'),
#  ('India', 'NNP'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('29', 'CD'),
#  (']', 'IN'),
#  ('The', 'DT'),
#  ('Dravidian', 'JJ'),
#  ('languages', 'NNS'),
#  ('of', 'IN'),
#  ('India', 'NNP'),
#  ('were', 'VBD'),
#  ('supplanted', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('northern', 'JJ'),
#  ('and', 'CC'),
#  ('western', 'JJ'),
#  ('regions', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('30', 'CD'),
#  (']', 'VBN'),
#  ('By', 'IN'),
#  ('400', 'CD'),
#  ('BCE', 'NNP'),
#  (',', ','),
#  ('stratification', 'NN'),
#  ('and', 'CC'),
#  ('exclusion', 'NN'),
#  ('by', 'IN'),
#  ('caste', 'NN'),
#  ('had', 'VBD'),
#  ('emerged', 'VBN'),
#  ('within', 'IN'),
#  ('Hinduism', 'NNP'),
#  (',', ','),
#  ('[', 'VBD'),
#  ('31', 'CD'),
#  (']', 'NN'),
#  ('and', 'CC'),
#  ('Buddhism', 'NNP'),
#  ('and', 'CC'),
#  ('Jainism', 'NNP'),
#  ('had', 'VBD'),
#  ('arisen', 'VBN'),
#  (',', ','),
#  ('proclaiming', 'VBG'),
#  ('social', 'JJ'),
#  ('orders', 'NNS'),
#  ('unlinked', 'VBD'),
#  ('to', 'TO'),
#  ('heredity', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('32', 'CD'),
#  (']', 'NNS'),
#  ('Early', 'RB'),
#  ('political', 'JJ'),
#  ('consolidations', 'NNS'),
#  ('gave', 'VBD'),
#  ('rise', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('loose-knit', 'JJ'),
#  ('Maurya', 'NNP'),
#  ('and', 'CC'),
#  ('Gupta', 'NNP'),
#  ('Empires', 'NNP'),
#  ('based', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Ganges', 'NNP'),
#  ('Basin', 'NNP'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('33', 'CD'),
#  (']', 'VBP'),
#  ('Their', 'PRP$'),
#  ('collective', 'JJ'),
#  ('era', 'NN'),
#  ('was', 'VBD'),
#  ('suffused', 'VBN'),
#  ('with', 'IN'),
#  ('wide-ranging', 'JJ'),
#  ('creativity', 'NN'),
#  (',', ','),
#  ('[', 'VBZ'),
#  ('34', 'CD'),
#  (']', 'NN'),
#  ('but', 'CC'),
#  ('also', 'RB'),
#  ('marked', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('declining', 'VBG'),
#  ('status', 'NN'),
#  ('of', 'IN'),
#  ('women', 'NNS'),
#  (',', ','),
#  ('[', 'VBD'),
#  ('35', 'CD'),
#  (']', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('incorporation', 'NN'),
#  ('of', 'IN'),
#  ('untouchability', 'NN'),
#  ('into', 'IN'),
#  ('an', 'DT'),
#  ('organised', 'JJ'),
#  ('system', 'NN'),
#  ('of', 'IN'),
#  ('belief', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('l', 'JJ'),
#  (']', 'NNP'),
#  ('[', 'NNP'),
#  ('36', 'CD'),
#  (']', 'VBD'),
#  ('The', 'DT'),
#  ('Middle', 'NNP'),
#  ('kingdoms', 'NNS'),
#  ('exported', 'VBD'),
#  ('Sanskrit', 'NNP'),
#  ('language', 'NN'),
#  (',', ','),
#  ('south', 'JJ'),
#  ('Indian', 'JJ'),
#  ('scripts', 'NNS'),
#  ('and', 'CC'),
#  ('religions', 'NNS'),
#  ('of', 'IN'),
#  ('Hinduism', 'NNP'),
#  ('and', 'CC'),
#  ('Buddhism', 'NNP'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('Southeast', 'NNP'),
#  ('Asia', 'NNP'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('37', 'CD'),
#  (']', 'NN'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('early', 'JJ'),
#  ('mediaeval', 'NN'),
#  ('era', 'NN'),
#  (',', ','),
#  ('Christianity', 'NNP'),
#  (',', ','),
#  ('Islam', 'NNP'),
#  (',', ','),
#  ('Judaism', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('Zoroastrianism', 'NNP'),
#  ('became', 'VBD'),
#  ('established', 'VBN'),
#  ('on', 'IN'),
#  ('India', 'NNP'),
#  ("'s", 'POS'),
#  ('southern', 'JJ'),
#  ('and', 'CC'),
#  ('western', 'JJ'),
#  ('coasts', 'NNS'),
#  ('.', '.'),
#  ('[', '$'),
#  ('38', 'CD'),
#  (']', 'NNP'),
#  ('Muslim', 'NNP'),
#  ('armies', 'NNS'),
#  ('from', 'IN'),
#  ('Central', 'NNP'),
#  ('Asia', 'NNP'),
#  ('intermittently', 'RB'),
#  ('overran', 'VBD'),
#  ('India', 'NNP'),
#  ("'s", 'POS'),
#  ('northern', 'JJ'),
#  ('plains', 'NNS'),
#  (',', ','),
#  ('[', 'VBP'),
#  ('39', 'CD'),
#  (']', 'NNP'),
#  ('eventually', 'RB'),
#  ('founding', 'VBG'),
#  ('the', 'DT'),
#  ('Delhi', 'NNP'),
#  ('Sultanate', 'NNP'),
#  ('and', 'CC'),
#  ('drawing', 'VBG'),
#  ('northern', 'JJ'),
#  ('India', 'NNP'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('cosmopolitan', 'JJ'),
#  ('networks', 'NNS'),
#  ('of', 'IN'),
#  ('mediaeval', 'JJ'),
#  ('Islam', 'NNP'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('40', 'CD'),
#  (']', 'NN'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('15th', 'JJ'),
#  ('century', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Vijayanagara', 'NNP'),
#  ('Empire', 'NNP'),
#  ('created', 'VBD'),
#  ('a', 'DT'),
#  ('long-lasting', 'JJ'),
#  ('composite', 'JJ'),
#  ('Hindu', 'NNP'),
#  ('culture', 'NN'),
#  ('in', 'IN'),
#  ('south', 'JJ'),
#  ('India', 'NNP'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('41', 'CD'),
#  (']', 'NN'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('Punjab', 'NNP'),
#  (',', ','),
#  ('Sikhism', 'NNP'),
#  ('emerged', 'VBD'),
#  (',', ','),
#  ('rejecting', 'VBG'),
#  ('institutionalised', 'VBN'),
#  ('religion', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('42', 'CD'),
#  (']', 'IN'),
#  ('The', 'DT'),
#  ('Mughal', 'NNP'),
#  ('Empire', 'NNP'),
#  (',', ','),
#  ('in', 'IN'),
#  ('1526', 'CD'),
#  (',', ','),
#  ('ushered', 'VBN'),
#  ('in', 'IN'),
#  ('two', 'CD'),
#  ('centuries', 'NNS'),
#  ('of', 'IN'),
#  ('relative', 'JJ'),
#  ('peace', 'NN'),
#  (',', ','),
#  ('[', 'FW'),
#  ('43', 'CD'),
#  (']', 'NN'),
#  ('leaving', 'VBG'),
#  ('a', 'DT'),
#  ('legacy', 'NN'),
#  ('of', 'IN'),
#  ('luminous', 'JJ'),
#  ('architecture', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('m', 'JJ'),
#  (']', 'NNP'),
#  ('[', 'NNP'),
#  ('44', 'CD'),
#  (']', 'NNP'),
#  ('Gradually', 'NNP'),
#  ('expanding', 'VBG'),
#  ('rule', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('British', 'JJ'),
#  ('East', 'NNP'),
#  ('India', 'NNP'),
#  ('Company', 'NNP'),
#  ('followed', 'VBD'),
#  (',', ','),
#  ('turning', 'VBG'),
#  ('India', 'NNP'),
#  ('into', 'IN'),
#  ('a', 'DT'),
#  ('colonial', 'JJ'),
#  ('economy', 'NN'),
#  ('but', 'CC'),
#  ('also', 'RB'),
#  ('consolidating', 'VBG'),
#  ('its', 'PRP$'),
#  ('sovereignty', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('45', 'CD'),
#  (']', 'JJ'),
#  ('British', 'JJ'),
#  ('Crown', 'NNP'),
#  ('rule', 'NN'),
#  ('began', 'VBD'),
#  ('in', 'IN'),
#  ('1858', 'CD'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('rights', 'NNS'),
#  ('promised', 'VBN'),
#  ('to', 'TO'),
#  ('Indians', 'NNPS'),
#  ('were', 'VBD'),
#  ('granted', 'VBN'),
#  ('slowly', 'RB'),
#  (',', ','),
#  ('[', 'VBD'),
#  ('46', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('47', 'CD'),
#  (']', 'NNS'),
#  ('but', 'CC'),
#  ('technological', 'JJ'),
#  ('changes', 'NNS'),
#  ('were', 'VBD'),
#  ('introduced', 'VBN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('modern', 'JJ'),
#  ('ideas', 'NNS'),
#  ('of', 'IN'),
#  ('education', 'NN'),
#  ('and', 'CC'),
#  ('public', 'JJ'),
#  ('life', 'NN'),
#  ('took', 'VBD'),
#  ('root', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('48', 'CD'),
#  (']', 'NN'),
#  ('A', 'NNP'),
#  ('pioneering', 'NN'),
#  ('and', 'CC'),
#  ('influential', 'JJ'),
#  ('nationalist', 'NN'),
#  ('movement', 'NN'),
#  ('emerged', 'VBD'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('was', 'VBD'),
#  ('noted', 'VBN'),
#  ('for', 'IN'),
#  ('nonviolent', 'JJ'),
#  ('resistance', 'NN'),
#  ('and', 'CC'),
#  ('became', 'VBD'),
#  ('the', 'DT'),
#  ('major', 'JJ'),
#  ('factor', 'NN'),
#  ('in', 'IN'),
#  ('ending', 'VBG'),
#  ('British', 'JJ'),
#  ('rule', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('49', 'CD'),
#  (']', 'JJ'),
#  ('[', '$'),
#  ('50', 'CD'),
#  (']', 'NN'),
#  ('In', 'IN'),
#  ('1947', 'CD'),
#  (',', ','),
#  ('the', 'DT'),
#  ('British', 'JJ'),
#  ('Indian', 'JJ'),
#  ('Empire', 'NNP'),
#  ('was', 'VBD'),
#  ('partitioned', 'VBN'),
#  ('into', 'IN'),
#  ('two', 'CD'),
#  ('independent', 'JJ'),
#  ('dominions', 'NNS'),
#  (',', ','),
#  ('[', 'VBP'),
#  ('51', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('52', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('53', 'CD'),
#  (']', 'NNP'),
#  ('[', 'VBD'),
#  ('54', 'CD'),
#  (']', 'IN'),
#  ('a', 'DT'),
#  ('Hindu-majority', 'NNP'),
#  ('dominion', 'NN'),
#  ('of', 'IN'),
#  ('India', 'NNP'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('Muslim-majority', 'NNP'),
#  ('dominion', 'NN'),
#  ('of', 'IN'),
#  ('Pakistan', 'NNP'),
#  (',', ','),
#  ('amid', 'IN'),
#  ('large-scale', 'JJ'),
#  ('loss', 'NN'),
#  ('of', 'IN'),
#  ('life', 'NN'),
#  ('and', 'CC'),
#  ('an', 'DT'),
#  ('unprecedented', 'JJ'),
#  ('migration', 'NN'),
#  ('.', '.'),
#  ('[', 'CC'),
#  ('55', 'CD'),
#  (']', 'NN')]

# %%
# 1.count how many verbs are there
# 2.print all nouns from this
verb_count = 0
nouns = []

for word, tag in pos:
  if tag.startswith('VB'):
    verb_count += 1
for word, tag in pos:
  if tag.startswith('NN'):
    nouns.append(word)

print("Number of verbs:", verb_count)
print("Nouns:", nouns)
# Out:
# Number of verbs: 82
# Nouns: ['India', 'Republic', 'India', '[', 'j', ']', ']', 'country', 'South', 'Asia', 'country', 'world', 'area', 'country', 'Ocean', 'south', 'Arabian', 'Sea', 'southwest', 'Bay', 'Bengal', 'southeast', 'shares', 'borders', 'Pakistan', 'west', ']', 'China', 'Nepal', 'Bhutan', 'north', 'Bangladesh', 'Myanmar', 'east', 'Ocean', 'India', 'vicinity', 'Sri', 'Lanka', 'Maldives', 'Andaman', 'Nicobar', 'Islands', 'share', 'maritime', 'border', 'Thailand', 'Myanmar', 'Indonesia', 'Modern', 'subcontinent', 'Africa', 'years', ']', ']', ']', 'occupation', 'forms', 'isolation', 'hunter-gatherers', 'region', 'Africa', 'diversity', ']', 'life', 'subcontinent', 'margins', 'Indus', 'river', 'basin', 'years', 'Indus', 'Valley', 'Civilisation', 'millennium', 'BCE', ']', 'BCE', 'form', 'Sanskrit', 'language', 'India', ']', 'evidence', 'today', 'hymns', 'Rigveda', 'tradition', 'Rigveda', 'records', 'dawning', 'Hinduism', 'India', 'languages', 'India', 'regions', 'BCE', 'stratification', 'exclusion', 'caste', 'Hinduism', ']', 'Buddhism', 'Jainism', 'orders', 'heredity', ']', 'consolidations', 'rise', 'Maurya', 'Gupta', 'Empires', 'Ganges', 'Basin', 'era', 'creativity', ']', 'status', 'women', ']', 'incorporation', 'untouchability', 'system', 'belief', ']', '[', 'Middle', 'kingdoms', 'Sanskrit', 'language', 'scripts', 'religions', 'Hinduism', 'Buddhism', 'Southeast', 'Asia', ']', 'mediaeval', 'era', 'Christianity', 'Islam', 'Judaism', 'Zoroastrianism', 'India', 'coasts', ']', 'Muslim', 'armies', 'Central', 'Asia', 'India', 'plains', ']', 'Delhi', 'Sultanate', 'India', 'networks', 'Islam', ']', 'century', 'Vijayanagara', 'Empire', 'Hindu', 'culture', 'India', ']', 'Punjab', 'Sikhism', 'religion', 'Mughal', 'Empire', 'centuries', 'peace', ']', 'legacy', 'architecture', ']', '[', ']', 'Gradually', 'rule', 'East', 'India', 'Company', 'India', 'economy', 'sovereignty', 'Crown', 'rule', 'rights', 'Indians', ']', ']', 'changes', 'ideas', 'education', 'life', 'root', ']', 'A', 'pioneering', 'nationalist', 'movement', 'resistance', 'factor', 'rule', ']', 'Empire', 'dominions', ']', ']', ']', 'Hindu-majority', 'dominion', 'India', 'Muslim-majority', 'dominion', 'Pakistan', 'loss', 'life', 'migration', ']']

# %%
# 1.count how many verbs are there
verbs = set()
for word, tag in pos:
    if tag.startswith('V') and word.isalpha():
        verbs.add(word)

# %%
len(verbs)
# Out:
# 50

# %%
# 2.print all nouns from this
nouns = set()
for word, tag in pos:
    if tag.startswith('N') and word.isalpha():
        nouns.add(word)

# %%
nouns
# Out:
# {'A',
#  'Africa',
#  'Andaman',
#  'Arabian',
#  'Asia',
#  'BCE',
#  'Bangladesh',
#  'Basin',
#  'Bay',
#  'Bengal',
#  'Bhutan',
#  'Buddhism',
#  'Central',
#  'China',
#  'Christianity',
#  'Civilisation',
#  'Company',
#  'Crown',
#  'Delhi',
#  'East',
#  'Empire',
#  'Empires',
#  'Ganges',
#  'Gradually',
#  'Gupta',
#  'Hindu',
#  'Hinduism',
#  'India',
#  'Indians',
#  'Indonesia',
#  'Indus',
#  'Islam',
#  'Islands',
#  'Jainism',
#  'Judaism',
#  'Lanka',
#  'Maldives',
#  'Maurya',
#  'Middle',
#  'Modern',
#  'Mughal',
#  'Muslim',
#  'Myanmar',
#  'Nepal',
#  'Nicobar',
#  'Ocean',
#  'Pakistan',
#  'Punjab',
#  'Republic',
#  'Rigveda',
#  'Sanskrit',
#  'Sea',
#  'Sikhism',
#  'South',
#  'Southeast',
#  'Sri',
#  'Sultanate',
#  'Thailand',
#  'Valley',
#  'Vijayanagara',
#  'Zoroastrianism',
#  'architecture',
#  'area',
#  'armies',
#  'basin',
#  'belief',
#  'border',
#  'borders',
#  'caste',
#  'centuries',
#  'century',
#  'changes',
#  'coasts',
#  'consolidations',
#  'country',
#  'creativity',
#  'culture',
#  'dawning',
#  'diversity',
#  'dominion',
#  'dominions',
#  'east',
#  'economy',
#  'education',
#  'era',
#  'evidence',
#  'exclusion',
#  'factor',
#  'form',
#  'forms',
#  'heredity',
#  'hymns',
#  'ideas',
#  'incorporation',
#  'isolation',
#  'j',
#  'kingdoms',
#  'language',
#  'languages',
#  'legacy',
#  'life',
#  'loss',
#  'margins',
#  'maritime',
#  'mediaeval',
#  'migration',
#  'millennium',
#  'movement',
#  'nationalist',
#  'networks',
#  'north',
#  'occupation',
#  'orders',
#  'peace',
#  'pioneering',
#  'plains',
#  'records',
#  'region',
#  'regions',
#  'religion',
#  'religions',
#  'resistance',
#  'rights',
#  'rise',
#  'river',
#  'root',
#  'rule',
#  'scripts',
#  'share',
#  'shares',
#  'south',
#  'southeast',
#  'southwest',
#  'sovereignty',
#  'status',
#  'stratification',
#  'subcontinent',
#  'system',
#  'today',
#  'tradition',
#  'untouchability',
#  'vicinity',
#  'west',
#  'women',
#  'world',
#  'years'}

# %%
# Extract and print all adjective-nouns pairs
adjective_noun_pairs = []
for i in range(len(pos) - 1):
    word, tag = pos[i]
    next_word, next_tag = pos[i + 1]
    if tag.startswith('JJ') and next_tag.startswith('NN'):
        adjective_noun_pairs.append((word, next_word))

# %%
adjective_noun_pairs
# Out:
# [('seventh-largest', 'country'),
#  ('populous', 'country'),
#  ('Indian', 'Ocean'),
#  ('Indian', 'Ocean'),
#  ('Indian', 'subcontinent'),
#  ('long', 'occupation'),
#  ('genetic', 'diversity'),
#  ('western', 'margins'),
#  ('third', 'millennium'),
#  ('archaic', 'form'),
#  ('Indo-European', 'language'),
#  ('oral', 'tradition'),
#  ('Dravidian', 'languages'),
#  ('western', 'regions'),
#  ('social', 'orders'),
#  ('political', 'consolidations'),
#  ('loose-knit', 'Maurya'),
#  ('collective', 'era'),
#  ('wide-ranging', 'creativity'),
#  ('organised', 'system'),
#  ('l', ']'),
#  ('Indian', 'scripts'),
#  ('early', 'mediaeval'),
#  ('western', 'coasts'),
#  ('northern', 'plains'),
#  ('northern', 'India'),
#  ('cosmopolitan', 'networks'),
#  ('mediaeval', 'Islam'),
#  ('15th', 'century'),
#  ('composite', 'Hindu'),
#  ('south', 'India'),
#  ('relative', 'peace'),
#  ('luminous', 'architecture'),
#  ('m', ']'),
#  ('British', 'East'),
#  ('colonial', 'economy'),
#  ('British', 'Crown'),
#  ('technological', 'changes'),
#  ('modern', 'ideas'),
#  ('public', 'life'),
#  ('influential', 'nationalist'),
#  ('nonviolent', 'resistance'),
#  ('major', 'factor'),
#  ('British', 'rule'),
#  ('Indian', 'Empire'),
#  ('independent', 'dominions'),
#  ('large-scale', 'loss'),
#  ('unprecedented', 'migration')]

# %% [markdown]
# # **Indian languages POS tagging**

# %%
nltk.download('indian')
from nltk.corpus import indian
from nltk import TnT
# Out:
# [nltk_data] Downloading package indian to /root/nltk_data...
# [nltk_data]   Unzipping corpora/indian.zip.

# %%
for name in indian.fileids():
    print(name)
# Out:
# bangla.pos
# hindi.pos
# marathi.pos
# telugu.pos

# %%
for x in indian.fileids():
    print(x)
    print(len(indian.words(x)))
# Out:
# bangla.pos
# 10281
# hindi.pos
# 9408
# marathi.pos
# 19066
# telugu.pos
# 9999

# %%
indian.sents('marathi.pos')
# Out:
# [["''", 'सनातनवाद्यांनी', 'व', 'प्रतिगाम्यांनी', 'समाज', 'रसातळाला', 'नेला', 'असताना', 'या', 'अंधारात', 'बाळशास्त्री', 'जांभेकर', 'यांनी', "'दर्पण'च्या", 'माध्यमातून', 'पहिली', 'ज्ञानज्योत', 'तेववली', ',', "''", 'असे', 'प्रतिपादन', 'नटसम्राट', 'प्रभाकर', 'पणशीकर', 'यांनी', 'केले', '.'], ['दर्पणकार', 'बाळशास्त्री', 'जांभेकर', 'यांच्या', '१९५व्या', 'जयंतीनिमित्त', 'महाराष्ट्र', 'संपादक', 'परिषद', 'व', 'सिंधुदुर्ग', 'जिल्हा', 'मराठी', 'पत्रकार', 'संघाच्या', 'वतीने', 'तसेच', 'महाराष्ट्र', 'जर्नलिस्ट', 'फाउंडेशन', 'व', 'महाराष्ट्र', 'ग्रामीण', 'पत्रकार', 'संघाच्या', 'सहभागाने', 'अभिवादन', 'कार्यक्रम', 'आयोजित', 'केला', 'होता', '.'], ...]

# %%
pos= indian.tagged_sents('marathi.pos')

# %%
pos
# Out:
# [[("''", 'SYM'), ('सनातनवाद्यांनी', 'NN'), ('व', 'CC'), ('प्रतिगाम्यांनी', 'NN'), ('समाज', 'NN'), ('रसातळाला', 'NN'), ('नेला', 'VM'), ('असताना', 'VAUX'), ('या', 'DEM'), ('अंधारात', 'NN'), ('बाळशास्त्री', 'NNPC'), ('जांभेकर', 'NNP'), ('यांनी', 'PRP'), ("'दर्पण'च्या", 'NNP'), ('माध्यमातून', 'NN'), ('पहिली', 'QO'), ('ज्ञानज्योत', 'NN'), ('तेववली', 'VM'), (',', 'SYM'), ("''", 'SYM'), ('असे', 'DEM'), ('प्रतिपादन', 'NN'), ('नटसम्राट', 'NNPC'), ('प्रभाकर', 'NNPC'), ('पणशीकर', 'NNP'), ('यांनी', 'PRP'), ('केले', 'VM'), ('.', 'SYM')], [('दर्पणकार', 'JJ'), ('बाळशास्त्री', 'NNPC'), ('जांभेकर', 'NNP'), ('यांच्या', 'PRP'), ('१९५व्या', 'QC'), ('जयंतीनिमित्त', 'NN'), ('महाराष्ट्र', 'NNPC'), ('संपादक', 'NNPC'), ('परिषद', 'NNP'), ('व', 'CC'), ('सिंधुदुर्ग', 'NNPC'), ('जिल्हा', 'NNPC'), ('मराठी', 'NNPC'), ('पत्रकार', 'NNPC'), ('संघाच्या', 'NNP'), ('वतीने', 'NN'), ('तसेच', 'PRP'), ('महाराष्ट्र', 'NNPC'), ('जर्नलिस्ट', 'NNPC'), ('फाउंडेशन', 'NNP'), ('व', 'CC'), ('महाराष्ट्र', 'NNPC'), ('ग्रामीण', 'NNPC'), ('पत्रकार', 'NNPC'), ('संघाच्या', 'NNP'), ('सहभागाने', 'NN'), ('अभिवादन', 'NN'), ('कार्यक्रम', 'NN'), ('आयोजित', 'JJ'), ('केला', 'VM'), ('होता', 'VAUX'), ('.', 'SYM')], ...]

# %%
# create  the object of tagger
tagger = TnT()

# %%
tagger.train(pos)

# %%
sent = 'रात्र असो का दिवस काही फरक पडत नाही.'

# %%
tagger.tag(nltk.word_tokenize(sent))
# Out:
# [('रात्र', 'Unk'),
#  ('असो', 'Unk'),
#  ('का', 'WQ'),
#  ('दिवस', 'NN'),
#  ('काही', 'QF'),
#  ('फरक', 'NN'),
#  ('पडत', 'VM'),
#  ('नाही', 'VAUX'),
#  ('.', 'SYM')]
